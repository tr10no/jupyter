# %% [markdown]
# #  Mengolah Data Menggunakan Pandas

# %% [markdown]
# ## Menginstall Library Pandas

# %% [markdown]
# Pada saat kita mengakses web Mybinder.org, kita akan dibuatkan environtment Python baru untuk bekerja dengan Jupyter Notebook. Untuk itu kita harus menginstall library-library yang kita butuhkan dalam proses coding yang kita buat. Cara menginstallnya mudah saja, yaitu dengan mengetik perintah sebagai berikut dan langsung eksekusi :
#
# !pip install pandas

# %%
# !pip install pandas matplotlib xlrd

# %% [markdown]
# ## Import Library yang kita butuhkan

# %%
import pandas as pd
import numpy as np
pd.set_option('float_format','{:f}'.format)

# %% [markdown]
# ## Membaca data dari file excel

# %%
data = pd.read_excel('indo_5.xls')

# %%
data
# Out:
#    Rata‑Rata Pengeluaran per Kapita Sebulan Untuk Makanan dan Bukan Makanan di Daerah Perkotaan dan Perdesaan Menurut Provinsi (rupiah), 2011-2021  \
# 0                                                 NaN
# 1                                            Provinsi
# 2                                                 NaN
# 3                                                Aceh
# 4                                      Sumatera Utara
# 5                                      Sumatera Barat
# 6                                                Riau
# 7                                               Jambi
# 8                                    Sumatera Selatan
# 9                                            Bengkulu
# 10                                            Lampung
# 11                          Kepulauan Bangka Belitung
# 12                                     Kepulauan Riau
# 13                                        DKI Jakarta
# 14                                         Jawa Barat
# ...

# %% [markdown]
# ## Membaca Data File Excel dengan mengggunakan parameter sebagai berikut :
# #### skiprows = 1 : untuk melewatkan baris yang akan dibaca (karena ada judul pada data excel tersebut)
# #### header = [1,2] : untuk menentukan header dari data, (data yang kita gunakan mempunyai 2 baris header --> 'Makanan'/'Non Makanan'/'Jumlah' dan deretan tahun)
# #### index_col=0 : index data terdapat pada kolom 0
# #### skipfooter=7 : untuk menghilangkan keterangan yang ada dibawah data (7 baris dihilangkan)

# %%
data = pd.read_excel('indo_5.xls', skiprows=1, header=[1,2],index_col=0, skipfooter=7)

# %% [markdown]
# ## Tampilan data yang sudah dirapihkan

# %%
data
# Out:
# Provinsi                  Makanan                                            \
#                              2011    2012    2013    2014    2015      2016
# Aceh                       329257  356132  371838  406835  415354  451 952
# Sumatera Utara             316343  344467  363363  398932  414566  472 220
# Sumatera Barat             358338  390870  419853  461404  472428  537 236
# Riau                       385949  432511  468503  481965  495322  556 747
# Jambi                      324197  336737  377133  403659  428457  464 381
# Sumatera Selatan           300453  308027  353213  390807  379945  446 364
# Bengkulu                   294975  330123  348161  384146  413263  447 384
# Lampung                    261519  283870  314408  340844  382368  412 617
# Kepulauan Bangka Belitung  391606  418496  491121  551960  578812  596 381
# Kepulauan Riau             431248  470371  508569  574814  602071  681 525
# ...

# %% [markdown]
# ## Mengubah data '-' menjadi 'NaN' Not a Number

# %%
data.replace('-', np.nan, inplace=True)
data.tail(12)
# Out:
# Provinsi                Makanan                                            \
#                            2011          2012          2013          2014
# Kalimantan Utara            NaN           NaN           NaN           NaN
# Sulawesi Utara    306126.000000 344033.000000 379814.000000 395996.000000
# Sulawesi Tengah   287260.000000 313730.000000 320823.000000 360961.000000
# Sulawesi Selatan  260240.000000 286410.000000 302903.000000 330220.000000
# Sulawesi Tenggara 240739.000000 271348.000000 284683.000000 291923.000000
# Gorontalo         256106.000000 269533.000000 276334.000000 338353.000000
# Sulawesi Barat    225501.000000 236901.000000 278355.000000 280751.000000
# Maluku            283407.000000 320271.000000 336750.000000 388284.000000
# Maluku Utara      281916.000000 286031.000000 337639.000000 367971.000000
# Papua Barat       367893.000000 354867.000000 416901.000000 445820.000000
# Papua             330865.000000 356651.000000 379876.000000 487272.000000
# ...

# %%
data.tail(12)
# Out:
# Provinsi                Makanan                                            \
#                            2011          2012          2013          2014
# Kalimantan Utara            NaN           NaN           NaN           NaN
# Sulawesi Utara    306126.000000 344033.000000 379814.000000 395996.000000
# Sulawesi Tengah   287260.000000 313730.000000 320823.000000 360961.000000
# Sulawesi Selatan  260240.000000 286410.000000 302903.000000 330220.000000
# Sulawesi Tenggara 240739.000000 271348.000000 284683.000000 291923.000000
# Gorontalo         256106.000000 269533.000000 276334.000000 338353.000000
# Sulawesi Barat    225501.000000 236901.000000 278355.000000 280751.000000
# Maluku            283407.000000 320271.000000 336750.000000 388284.000000
# Maluku Utara      281916.000000 286031.000000 337639.000000 367971.000000
# Papua Barat       367893.000000 354867.000000 416901.000000 445820.000000
# Papua             330865.000000 356651.000000 379876.000000 487272.000000
# ...

# %% [markdown]
# ## Menampilkan Informasi Baris dan Kolom Data yang kita miliki
# Pada kolom Makanan, 2016 type data Object String (dalam data terdapat spasi) sehingga harus diubah menjadi float

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, Aceh to Indonesia
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Makanan, 2011)     34 non-null     float64
#  1   (Makanan, 2012)     34 non-null     float64
#  2   (Makanan, 2013)     34 non-null     float64
#  3   (Makanan, 2014)     34 non-null     float64
#  4   (Makanan, 2015)     35 non-null     int64
#  5   (Makanan, 2016)     35 non-null     object
#  6   (Makanan, 2017)     35 non-null     float64
#  7   (Makanan, 2018)     35 non-null     float64
#  8   (Makanan, 2019)     35 non-null     float64
#  9   (Makanan, 2020)     35 non-null     float64
#  10  (Makanan, 2021)     35 non-null     float64
#  11  (Nonmakanan, 2011)  34 non-null     float64
#  12  (Nonmakanan, 2012)  34 non-null     float64
#  13  (Nonmakanan, 2013)  34 non-null     float64
#  14  (Nonmakanan, 2014)  34 non-null     float64
# ...

# %%
data['Makanan', 2016].values
# Out:
# array(['451 952 ', '472 220 ', '537 236 ', '556 747 ', '464 381 ',
#        '446 364 ', '447 384 ', '412 617 ', '596 381 ', '681 525 ',
#        '692 207 ', '477 814 ', '371 605 ', '434 004 ', '427 191 ',
#        '532 389 ', '465 993 ', '410 112 ', '312 312 ', '451 222 ',
#        '546 306 ', '531 127 ', '587 920 ', '549 467 ', '484 938 ',
#        '420 182 ', '407 389 ', '371 733 ', '380 934 ', '357 586 ',
#        '431 484 ', '413 580 ', '482 624 ', '524 592 ', '460 639'],
#       dtype=object)

# %% [markdown]
# ## Fungsi mengubah type Object String menjadi Float

# %%
def object_to_float(table, column_list):
    '''
    Replace string datatype from `table` in `column_list` 
    into float
    
    Parameters:
    -----------
    table : dataframe
    column_list : multi index columns
    '''
    output_list = []
    for string in table[column_list].tolist():
        float_data = float(string.strip().replace(' ',''))
        output_list.append(float_data)
    return output_list

# %%
string_cols_list = [('Makanan', 2016), ('Nonmakanan', 2016), ('Jumlah', 2016)]

for string_col in string_cols_list:
    data[string_col] = object_to_float(data, string_col)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, Aceh to Indonesia
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Makanan, 2011)     34 non-null     float64
#  1   (Makanan, 2012)     34 non-null     float64
#  2   (Makanan, 2013)     34 non-null     float64
#  3   (Makanan, 2014)     34 non-null     float64
#  4   (Makanan, 2015)     35 non-null     int64
#  5   (Makanan, 2016)     35 non-null     float64
#  6   (Makanan, 2017)     35 non-null     float64
#  7   (Makanan, 2018)     35 non-null     float64
#  8   (Makanan, 2019)     35 non-null     float64
#  9   (Makanan, 2020)     35 non-null     float64
#  10  (Makanan, 2021)     35 non-null     float64
#  11  (Nonmakanan, 2011)  34 non-null     float64
#  12  (Nonmakanan, 2012)  34 non-null     float64
#  13  (Nonmakanan, 2013)  34 non-null     float64
#  14  (Nonmakanan, 2014)  34 non-null     float64
# ...

# %%
data['Makanan'].head()
# Out:
#                         2011          2012          2013          2014  \
# Aceh           329257.000000 356132.000000 371838.000000 406835.000000
# Sumatera Utara 316343.000000 344467.000000 363363.000000 398932.000000
# Sumatera Barat 358338.000000 390870.000000 419853.000000 461404.000000
# Riau           385949.000000 432511.000000 468503.000000 481965.000000
# Jambi          324197.000000 336737.000000 377133.000000 403659.000000
#
#                   2015          2016          2017          2018  \
# Aceh            415354 451952.000000 529161.554079 547668.075277
# Sumatera Utara  414566 472220.000000 522766.380161 554754.231500
# Sumatera Barat  472428 537236.000000 584045.241832 604871.244780
# Riau            495322 556747.000000 603401.298422 599873.401548
# Jambi           428457 464381.000000 538359.984626 555989.048493
#
#                         2019          2020          2021
# Aceh           559299.713114 595634.826083 643591.403149
# ...

# %%
data_makanan = data['Makanan']
data_makanan
# Out:
#                                    2011          2012          2013  \
# Aceh                      329257.000000 356132.000000 371838.000000
# Sumatera Utara            316343.000000 344467.000000 363363.000000
# Sumatera Barat            358338.000000 390870.000000 419853.000000
# Riau                      385949.000000 432511.000000 468503.000000
# Jambi                     324197.000000 336737.000000 377133.000000
# Sumatera Selatan          300453.000000 308027.000000 353213.000000
# Bengkulu                  294975.000000 330123.000000 348161.000000
# Lampung                   261519.000000 283870.000000 314408.000000
# Kepulauan Bangka Belitung 391606.000000 418496.000000 491121.000000
# Kepulauan Riau            431248.000000 470371.000000 508569.000000
# DKI Jakarta               457669.000000 519028.000000 603269.000000
# Jawa Barat                297590.000000 340757.000000 371881.000000
# Jawa Tengah               229775.000000 262761.000000 281921.000000
# ...

# %% [markdown]
# ## Menghapus baris data terakhir index='Indonesia'

# %%
data_makanan = data_makanan.drop('Indonesia')

# %%
data_makanan.tail()
# Out:
#                         2011          2012          2013          2014  \
# Sulawesi Barat 225501.000000 236901.000000 278355.000000 280751.000000
# Maluku         283407.000000 320271.000000 336750.000000 388284.000000
# Maluku Utara   281916.000000 286031.000000 337639.000000 367971.000000
# Papua Barat    367893.000000 354867.000000 416901.000000 445820.000000
# Papua          330865.000000 356651.000000 379876.000000 487272.000000
#
#                   2015          2016          2017          2018  \
# Sulawesi Barat  330890 357586.000000 393942.699286 433929.170457
# Maluku          420732 431484.000000 485032.585466 491426.440381
# Maluku Utara    421216 413580.000000 486734.449738 502810.203249
# Papua Barat     512796 482624.000000 551032.098615 614330.227397
# Papua           473382 524592.000000 638353.510585 623986.571346
#
#                         2019          2020          2021
# Sulawesi Barat 445426.776340 457059.215248 453030.944533
# ...

# %% [markdown]
# ## Menyimpan data kedalam file csv kemudian membaca data csv tersebut untuk dilakukan pengolahan data

# %%
datacsv = data_makanan.to_csv('data_makanan_csv.csv')

# %%
datacsv = pd.read_csv('data_makanan_csv.csv')

# %% [markdown]
# ## Mengganti nama kolom Unnamed menjadi prov

# %%
datacsv.rename(columns={'Unnamed: 0':'prov'}, inplace=True)

# %%
datacsv.head()
# Out:
#              prov          2011          2012          2013          2014  \
# 0            Aceh 329257.000000 356132.000000 371838.000000 406835.000000
# 1  Sumatera Utara 316343.000000 344467.000000 363363.000000 398932.000000
# 2  Sumatera Barat 358338.000000 390870.000000 419853.000000 461404.000000
# 3            Riau 385949.000000 432511.000000 468503.000000 481965.000000
# 4           Jambi 324197.000000 336737.000000 377133.000000 403659.000000
#
#      2015          2016          2017          2018          2019  \
# 0  415354 451952.000000 529161.554079 547668.075277 559299.713114
# 1  414566 472220.000000 522766.380161 554754.231500 576322.718748
# 2  472428 537236.000000 584045.241832 604871.244780 609257.912548
# 3  495322 556747.000000 603401.298422 599873.401548 621747.612410
# 4  428457 464381.000000 538359.984626 555989.048493 560541.556767
#
#            2020          2021
# 0 595634.826083 643591.403149
# 1 598244.670593 607811.561120
# ...

# %% [markdown]
# ## Membaca file csv dan memilih beberapa kolom untuk ditampilkan

# %%
data_1920 = pd.read_csv('data_makanan_csv.csv',usecols=[0,9,10])
data_1920.head()
# Out:
#        Unnamed: 0          2019          2020
# 0            Aceh 559299.713114 595634.826083
# 1  Sumatera Utara 576322.718748 598244.670593
# 2  Sumatera Barat 609257.912548 644852.656921
# 3            Riau 621747.612410 668073.754643
# 4           Jambi 560541.556767 590173.342721

# %%
data_1920 = data_1920.rename(columns={'Unnamed: 0':'prov'})

# %% [markdown]
# ## Mengurutkan data berdasarkan kolom tahun 2019 dan 2020 kemudian menampilkan dalam bentuk visual

# %%
data_1920 = data_1920.sort_values(by=['2020','2019'], ascending=False)

# %%
data_1920.plot.bar(x='prov',ylabel='Pengeluaran per Kapita',title='Pengeluaran per Kapita per Provinsi',stacked=False,figsize=(14,6))
# Out:
# <AxesSubplot:title={'center':'Pengeluaran per Kapita per Provinsi'}, xlabel='prov', ylabel='Pengeluaran per Kapita'>
